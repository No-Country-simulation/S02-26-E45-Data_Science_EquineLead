# %%
#%pip install pandas
#%pip install pyarrow fastparquet
#%pip install matplotlib
#%pip install seaborn

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_parquet(
    r"C:\Users\veter\Desktop\nocountry\equipo_45\equinenow_horses_listings.parquet",
    engine='fastparquet'
)

# %%
pd.options.display.max_columns = None
df
# Out:
#      Horse_ID          Breed                Name    Gender      Foal Date  \
# 0     1605454      Miniature      HERSHEY'S LUCY     Filly  Aug 30th 2025
# 1     1601263  Quarter Horse        Bar X Pumbaa   Gelding   Jan 1st 2020
# 2     1596672   Standardbred                None     Filly           None
# 3     1602502          Draft        Sherman tank   Gelding  Feb 29th 2020
# 4     1603216  Quarter Horse  Invitation to Roan   Gelding  Apr 24th 2017
# ...       ...            ...                 ...       ...            ...
# 1900  1605582       Friesian                None   Gelding           None
# 1901  1602484        Unknown            Sapphire      Mare           None
# 1902  1602438  Quarter Horse                None   Gelding           None
# 1903  1603956     Saddlebred            STUD FEE  Stallion           None
# 1904  1588034     Andalusian             Amadeus      Colt   Apr 2nd 2025
#
#      In Foal Height (hh) Weight (lbs) Temperament Ad Number     Ad Created  \
# 0         No         6.0        150.0      5 / 10   1605454  Jan 22nd 2026
# 1         No        14.2       1000.0      1 / 10   1601263   Dec 1st 2025
# 2         No        16.0        750.0      5 / 10   1596672  Jan 12th 2026
# 3         No        15.3       1900.0      1 / 10   1602502  Dec 11th 2025
# 4         No        16.0       1200.0      6 / 10   1603216  Dec 21st 2025
# ...      ...         ...          ...         ...       ...            ...
# 1900      No        16.1       1300.0      2 / 10   1605582  Jan 25th 2026
# 1901      No        13.0        800.0      5 / 10   1602484  Dec 10th 2025
# 1902      No        14.3       1000.0      2 / 10   1602438  Dec 10th 2025
# 1903      No        16.3       1400.0      1 / 10   1603956   Jan 2nd 2026
# 1904      No        13.0        600.0      5 / 10   1588034  Jan 30th 2026
#
#         Last Update         Location    Price  \
# 0     Jan 22nd 2026  Millersburg, OH   $1,900
# 1      Feb 6th 2026  San Antonio, TX  $35,000
# 2     Jan 12th 2026  Blairsville, PA   $4,500
# 3     Dec 11th 2025          Ava, MO  $12,500
# 4     Dec 21st 2025       Auburn, PA   $7,500
# ...             ...              ...      ...
# 1900  Jan 25th 2026         Bath, NC   $8,500
# 1901  Dec 10th 2025     Marshall, NC   $1,200
# 1902  Dec 10th 2025        Ocala, FL   $9,500
# 1903   Jan 2nd 2026       Monroe, LA     $700
# 1904  Jan 30th 2026  Floresville, TX  $10,000
#
#                                    Horse Profile  \
# 0     https://www.equinenow.com/horse-ad-1605454
# 1     https://www.equinenow.com/horse-ad-1601263
# 2     https://www.equinenow.com/horse-ad-1596672
# 3     https://www.equinenow.com/horse-ad-1602502
# 4     https://www.equinenow.com/horse-ad-1603216
# ...                                          ...
# 1900  https://www.equinenow.com/horse-ad-1605582
# 1901  https://www.equinenow.com/horse-ad-1602484
# 1902  https://www.equinenow.com/horse-ad-1602438
# 1903  https://www.equinenow.com/horse-ad-1603956
# 1904  https://www.equinenow.com/horse-ad-1588034
#
#                                                  Skills  \
# 0                                     Kid Safe, Therapy
# - **Gender:** Genero.  en caballos definen su etapa de vida, género y estado reproductivo. Los principales son: Filly (potranca < 4 años), Colt (potro macho < 4 años), Mare (yegua), Stallion (semental/macho entero), Gelding (caballo castrado), Foal (potro recién nacido), Weanling (destetado), Yearling (añojo), Broodmare (yegua de cría), Unborn (no nacido) y Unknown (desconocido).
# - **Foal Date:** Fecha de nacimiento del potro/potranca.
# - **In Foal:** Si la Yegua está embarazada o preñada (en gestación)
# - **Height (hh):**"manos de altura" (hands high en inglés). Es la unidad de medida tradicional utilizada para medir la altura de un equino desde el suelo hasta la cruz (la base del cuello). Una mano equivale a 4 pulgadas o 10.16 cm.
# - **Weight (lbs):** Peso corporal del animal medido en libras (libras-peso)
# - **Color:** Describe los diferentes colores de pelaje (capas) y patrones de manchas en caballos, incluyendo bases sólidas, diluciones, patrones píos (manchas) y ruanos.
# - **Registry:** Incripción oficial de un ejemplar
# - **Temperament:** Personalidad innata, comportamiento general y forma de reaccionar ante estímulos del entorno
# - **Ad Number:** Número de identificación del caballo
# - **Ad Created:** Fecha de publicación
# - **Last Update:** Ultima actualiación
# - **Location:** Ubicación
# - **Price:** Precio
# - **Horse Profile:** Perfil del caballo (página web)
# - **Skills:** Las habilidades, capacidades físicas y técnicas entrenadas (velocidad, resistencia, salto, doma, trote, galope) que determinan su rendimiento
# - **Comments:** Comentarios.
# - **Shipping:** Envío.
# - **Company Name:** Nombre de la empresa.
# - **Company Profile:** Perfil de la empresa.
# - **State Bred:** Se refiere a un ejemplar que ha nacido y ha sido registrado en un estado específico de Estados Unidos, cumpliendo con los requisitos de residencia y cría de la asociación de criadores de ese lugar.
# - **Markings:** Manchas o zonas de pelo blanco que presentan de forma natural, principalmente en la cabeza y las extremidades, sobre una capa base más oscura
# - **Registry Number:** Número de Registro.

# %%
# revisando datos unicos en cada columna
for col in df.columns:
  print(f"valores únicos en la columna'{col}': {df[col].nunique()}")
  if df[col].nunique() < 50: #imprima los valores solamente si no hay muchos
    print(df[col].unique())
    print('-' * 100) #linea divisoria para mejorar visualización
# Out:
# valores únicos en la columna'Horse_ID': 1905
# valores únicos en la columna'Breed': 72
# valores únicos en la columna'Name': 1088
# valores únicos en la columna'Gender': 11
# ['Filly' 'Gelding' 'Mare' 'Colt' 'Foal' 'Stallion' 'Unborn Foal' 'Unknown'
#  'Broodmare' 'Weanling' 'Yearling']
# ----------------------------------------------------------------------------------------------------
# valores únicos en la columna'Foal Date': 688
# valores únicos en la columna'In Foal': 2
# ['No' 'Yes']
# ----------------------------------------------------------------------------------------------------
# valores únicos en la columna'Height (hh)': 71
# valores únicos en la columna'Weight (lbs)': 84
# valores únicos en la columna'Temperament': 10
# ['5 / 10' '1 / 10' '6 / 10' '3 / 10' '2 / 10' '4 / 10' '8 / 10' '9 / 10'
#  '7 / 10' '10 / 10']
# ----------------------------------------------------------------------------------------------------
# valores únicos en la columna'Ad Number': 1905
# valores únicos en la columna'Ad Created': 94
# valores únicos en la columna'Last Update': 89
# valores únicos en la columna'Location': 796
# valores únicos en la columna'Price': 183
# valores únicos en la columna'Horse Profile': 1905
# valores únicos en la columna'Skills': 1156
# valores únicos en la columna'Comments': 1785
# valores únicos en la columna'Shipping': 562
# valores únicos en la columna'Company Name': 366
# valores únicos en la columna'Company Profile': 316
# valores únicos en la columna'Color': 41
# [None 'Bay' 'Chestnut' 'Buckskin' 'Sorrel' 'Tobiano' 'Grey' 'Black'
#  'White' 'Blue Roan' 'Dun' 'Piebald' 'Perlino' 'Red Roan' 'Bay Roan'
#  'Dunskin' 'Overo' 'Isabelo' 'Other' 'Roan' 'Palomino' 'Bay Overo' 'Brown'
#  'Red Dun' 'Grulla' 'Black Overo' 'Cremello' 'Champagne' 'slbr' 'Pinto'
#  'Chocolate' 'Chestnut Overo' 'Dun w/ Blk Points' 'Tovero' 'Unknown'
#  'Sorrel Overo' 'Liver Chestnut' 'Smokey Black' 'Buckskin Overo' 'Sabino'
#  'silb' 'Dunalino']
# ----------------------------------------------------------------------------------------------------
# valores únicos en la columna'Registry': 63
# valores únicos en la columna'Markings': 321
# valores únicos en la columna'State Bred': 51
# valores únicos en la columna'Registry Number': 271

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1905 entries, 0 to 1904
# Data columns (total 25 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Horse_ID         1905 non-null   object
#  1   Breed            1905 non-null   object
#  2   Name             1224 non-null   object
#  3   Gender           1905 non-null   object
#  4   Foal Date        1104 non-null   object
#  5   In Foal          1905 non-null   object
#  6   Height (hh)      1554 non-null   object
#  7   Weight (lbs)     1439 non-null   object
#  8   Temperament      1905 non-null   object
#  9   Ad Number        1905 non-null   object
#  10  Ad Created       1905 non-null   object
#  11  Last Update      1905 non-null   object
#  12  Location         1905 non-null   object
#  13  Price            1905 non-null   object
#  14  Horse Profile    1905 non-null   object
#  15  Skills           1342 non-null   object
#  16  Comments         1905 non-null   object
#  17  Shipping         1186 non-null   object
#  18  Company Name     975 non-null    object
#  19  Company Profile  888 non-null    object
#  20  Color            1473 non-null   object
#  21  Registry         722 non-null    object
#  22  Markings         489 non-null    object
#  23  State Bred       822 non-null    object
#  24  Registry Number  320 non-null    object
# dtypes: object(25)
# memory usage: 372.2+ KB

# %%
#valores duplicados y nulos
# Verificando si hay duplicados
duplicados = df.duplicated().sum()
print(f"Número de duplicados: {duplicados}")

#verificamos si hay valores Nulos
#es .values para que nos entregue un numero y no nos entregue un objeto
valores_nulos = df.isnull().values.sum()
print(f"\nValores nulos por comlumna: ")
print(valores_nulos[valores_nulos > 0])
# Out:
# Número de duplicados: 0
#
# Valores nulos por comlumna:
# [11227]

# %%
#nulos por columna
print(df.isnull().sum())
# Out:
# Horse_ID              0
# Breed                 0
# Name                681
# Gender                0
# Foal Date           801
# In Foal               0
# Height (hh)         351
# Weight (lbs)        466
# Temperament           0
# Ad Number             0
# Ad Created            0
# Last Update           0
# Location              0
# Price                 0
# Horse Profile         0
# Skills              563
# Comments              0
# Shipping            719
# Company Name        930
# Company Profile    1017
# Color               432
# Registry           1183
# Markings           1416
# State Bred         1083
# Registry Number    1585
# dtype: int64

# %%
# Ver porcentaje de nulos por columna
porcentaje_nulos = (df.isnull().sum() / len(df)) * 100
print(porcentaje_nulos.sort_values(ascending=False))
# Out:
# Registry Number    83.202100
# Markings           74.330709
# Registry           62.099738
# State Bred         56.850394
# Company Profile    53.385827
# Company Name       48.818898
# Foal Date          42.047244
# Shipping           37.742782
# Name               35.748031
# Skills             29.553806
# Weight (lbs)       24.461942
# Color              22.677165
# Height (hh)        18.425197
# Horse_ID            0.000000
# In Foal             0.000000
# Breed               0.000000
# Gender              0.000000
# Temperament         0.000000
# Comments            0.000000
# Price               0.000000
# Horse Profile       0.000000
# Ad Created          0.000000
# Last Update         0.000000
# Ad Number           0.000000
# Location            0.000000
# dtype: float64

# %%
#crear copia del df 
df_final = df.copy()

# %%
#borrar columnas que no sirven 
cols_a_borrar = ['Ad Number', 'Registry Number', 'State Bred']
df_final = df_final.drop(columns=cols_a_borrar, errors='ignore')

# %%
#limpieza de texto
cols_texto = df_final.select_dtypes(include=['object']).columns
for col in cols_texto:
    df_final[col] = df_final[col].astype(str).str.lower().str.strip()
    #reemplazar nan o none por nulos reales
    df_final[col] = df_final[col].replace({'nan': None, 'none':None, 'sin información': None})

# %%
#limpieza de $ y coma 
df_final['Price'] = df_final['Price'].astype(str).str.replace('$', '', regex=False).str.replace(',', '', regex=False)

# %%
#forazando números, si falla se coloca NaN
cols_numericas = ['Price', 'Height (hh)', 'Weight (lbs)']
for col in cols_numericas:
    df_final[col] = pd.to_numeric(df_final[col], errors='coerce')

# %%
#fechas 
cols_fechas = ['Foal Date', 'Ad Created', 'Last Update']
for col in cols_fechas:
    df_final[col] = pd.to_datetime(df_final[col], errors='coerce', format='mixed')

# %%
#calcular edad
#si tenemos fecha de nacimiento calculamos la edad exacta 
now = pd.Timestamp.now()
df_final['Age'] = (now - df_final['Foal Date']).dt.days / 365
df_final['Age'] = df_final['Age'].round(1)

# %%
#detectar marcas de valor(cara)
palabras_clave = 'star|blaze|strip|bald|white face|snipe'
# Rellenamos nulos temporales en Markings para poder buscar
df_final['Markings'] = df_final['Markings'].fillna('sin información')
df_final['Has_Face_Markings'] = df_final['Markings'].str.contains(palabras_clave, regex=True).astype(int)

# %%
# 4.1. Rellenar EDAD y PRECIO usando la Mediana por RAZA 
# (Si es un Pony, usa la edad/precio promedio de Ponys)
cols_a_rellenar = ['Price', 'Height (hh)', 'Weight (lbs)', 'Age']

for col in cols_a_rellenar:
    #intenta rellenar con la mediana de su raza
    df_final[col] = df_final[col].fillna(df_final.groupby('Breed')[col].transform('median'))
    #si la raza es unica y no tiene mediana , usa la mediana global 
    df_final[col] = df_final[col].fillna(df_final[col].median())

# %%
#rellenar fechas faltantes
# si no hay fecha de actualización , se asume la de creación 
df_final['Last Update'] = df_final['Last Update'].fillna(df_final[col].median())

# %%
#rellenar texto restante
cols_texto_final = df_final.select_dtypes(include=['object', 'string']).columns
df_final[cols_texto_final] = df_final[cols_texto_final].fillna('sin información')

# %%
#limpieza final 
df_final = df_final.drop(columns=['Foal Date'], errors='ignore')

# %%
#verificacion 
print("---RESUMEN FINAL---")
print(f"Total Nulos: {df_final.isnull().sum().sum()}")
print("\n---Muestra de Datos---")
print(df_final[['Breed', 'Age', 'Price', 'Has_Face_Markings']])
# Out:
# ---RESUMEN FINAL---
# Total Nulos: 0
#
# ---Muestra de Datos---
#               Breed   Age    Price  Has_Face_Markings
# 0         miniature  0.50   1900.0                  0
# 1     quarter horse  6.10  35000.0                  0
# 2      standardbred  7.65   4500.0                  0
# 3             draft  6.00  12500.0                  0
# 4     quarter horse  8.80   7500.0                  0
# ...             ...   ...      ...                ...
# 1900       friesian  3.80   8500.0                  0
# 1901        unknown  6.30   1200.0                  0
# 1902  quarter horse  5.80   9500.0                  0
# 1903     saddlebred  8.35    700.0                  0
# 1904     andalusian  0.90  10000.0                  0
#
# [1905 rows x 4 columns]

# %%
df_final.sample(3)
# Out:
#      Horse_ID          Breed             Name   Gender In Foal  Height (hh)  \
# 118   1599101     welsh pony         starfire  gelding      no         12.0
# 1678  1599784  quarter horse  ds kings outlaw     colt      no         15.0
# 166   1604689        belgian             levi  gelding      no         17.3
#
#       Weight (lbs) Temperament Ad Created Last Update         Location  \
# 118          500.0      5 / 10 2025-11-10  2025-12-09  worthington, oh
# 1678        1100.0      3 / 10 2025-11-09  2026-01-02   story city, ia
# 166         1200.0      3 / 10 2026-01-13  2026-01-13     stafford, va
#
#        Price                               Horse Profile  \
# 118   5995.0  https://www.equinenow.com/horse-ad-1599101
# 1678  3500.0  https://www.equinenow.com/horse-ad-1599784
# 166   5500.0  https://www.equinenow.com/horse-ad-1604689
#
#                                                  Skills  \
# 118   all around, beginner, companion, driving, less...
# 1678                                    sin información
# 166                   beginner, driving, western riding
#
#                                                Comments  \
# 118   hc starfire (by caris absolutely blue and out ...
# 1678  ds kings outlawthis sweet guy is an amazing pr...
# 166   beautiful 17.2hh belgian draft, 4 years old, w...
#
#                                                Shipping         Company Name  \
# 118   hillary is a world class hunter/jumper/dressag...  hillary carlson llc
# 1678  small farm in central iowa that specializes in...            aa horses
# 166                                     sin información      sin información
#
#                                         Company Profile            Color  \
# 118   https://www.equinenow.com/farm/hillary-carlson...            black
# 1678           https://www.equinenow.com/farm-id-332404              bay
# 166                                     sin información  sin información
#
#              Registry                                           Markings  Age  \
# 118             wpcsa  narrow blaze and snip conjoined, entering righ...  6.4
# 1678  sin información                                    sin información  5.8
# 166   sin información                                    sin información  4.1
#
#       Has_Face_Markings
# 118                   1
# 1678                  0
# 166                   0

# %%
import re

# Función para detectar si un texto tiene "mugre" (algo que no sea letra, número o espacio simple)
def tiene_caracteres_raros(texto):
    if pd.isna(texto): return False
    # Busca cualquier cosa que NO sea letra, número, espacio, punto, coma o guión
    # Si encuentra un emoji o un asterisco, devuelve True
    return bool(re.search(r'[^a-zA-Z0-9\s\.\,\-ñÑáéíóúÁÉÍÓÚ]', str(texto)))

# Revisamos las columnas de texto
cols_texto = df_final.select_dtypes(include=['object', 'string']).columns

print("--- Filas con caracteres raros detectados ---")
for col in cols_texto:
    # Contamos cuántas filas tienen suciedad
    sucias = df_final[col].apply(tiene_caracteres_raros).sum()
    if sucias > 0:
        print(f"Columna '{col}': {sucias} filas sucias")
        # Mostramos un ejemplo para que veas qué encontró
        ejemplo = df_final[df_final[col].apply(tiene_caracteres_raros)][col].iloc[0]
        print(f"   Ejemplo: {ejemplo}")
# Out:
# --- Filas con caracteres raros detectados ---
# Columna 'Name': 88 filas sucias
#    Ejemplo: hershey's lucy
# Columna 'Temperament': 1905 filas sucias
#    Ejemplo: 5 / 10
# Columna 'Location': 3 filas sucias
#    Ejemplo: sink’s groves, wv
# Columna 'Horse Profile': 1905 filas sucias
#    Ejemplo: https://www.equinenow.com/horse-ad-1605454
# Columna 'Comments': 1675 filas sucias
#    Ejemplo: hershey's lucy is born 8-30-25. here is the most adorable mini calf. her mother is a mini angus and the daddy was a mini hereford. lucy was born and raised in the petting area. she is very gentle and loves attention. if your looking to start your own little herd lucy is out of great stock. if you have thought it would be fun to have a family cow but didnt like the size our the mess they create why not try a mini so much smaller and a very neat little cow. for more info contact john @ 330 600 0197
# Columna 'Shipping': 601 filas sucias
#    Ejemplo: we can help you arrange shipping!!!
# Columna 'Company Name': 23 filas sucias
#    Ejemplo: hershberger's farm
# Columna 'Company Profile': 888 filas sucias
#    Ejemplo: https://www.equinenow.com/farm/hershbergers-farm.htm
# Columna 'Color': 10 filas sucias
#    Ejemplo: dun w/ blk points
# Columna 'Markings': 36 filas sucias
#    Ejemplo: black & white

# %%
# Definimos el patrón de lo que SÍ queremos mantener
# [^ ... ] significa "Borra todo lo que NO sea esto"
# a-z0-9: Letras y números
# \s: Espacios
# ñÑáéíóú...: Acentos y eñes (por si acaso)
# \.\,\-\': Puntos, comas, guiones y apóstrofes (para nombres como O'Connor)
patron_a_mantener = r'[^a-zA-Z0-9\sñÑáéíóúÁÉÍÓÚ\.\,\-\']'

print("Limpiando asteriscos y emojis... 🧹")

for col in cols_texto:
    # 1. Reemplazamos todo lo que NO sea el patrón con vacío ''
    df_final[col] = df_final[col].astype(str).str.replace(patron_a_mantener, '', regex=True)
    
    # 2. Quitamos espacios dobles que hayan quedado 
    df_final[col] = df_final[col].str.replace(r'\s+', ' ', regex=True).str.strip()

print("¡Limpieza terminada! ✨")

# Verificación
print(df_final[['Name', 'Comments']].head())
# Out:
# Limpiando asteriscos y emojis... 🧹
# ¡Limpieza terminada! ✨
#                  Name                                           Comments
# 0      hershey's lucy  hershey's lucy is born 8-30-25. here is the mo...
# 1        bar x pumbaa  elite aqha gelding proven bloodlines family fr...
# 2     sin información  lacy is a fancy colored blue eyed splash white...
# 3        sherman tank  meet our sherman tankhe's stouta 5yo - coming ...
# 4  invitation to roan  rio is a 2017 gelding. hes an amazing horse, b...

# %%
# --- TRADUCCIÓN RÁPIDA (Español -> Inglés) 🇺🇸 ---

# 1. Seleccionamos las columnas de texto
cols_texto = df_final.select_dtypes(include=['object', 'string']).columns

# 2. Definimos qué cambiar (incluye variantes por si acaso)
traduccion = {
    'sin información': 'unknown',
    'sin informacion': 'unknown',   # Por si falta la tilde
    'no disponible': 'not provided',
    'consultar': 'ask seller',
    'nan': 'unknown',
    'none': 'unknown'
}

print(f"--- Traduciendo {len(cols_texto)} columnas... ---")

for col in cols_texto:
    # Aseguramos que sea texto y minúsculas
    df_final[col] = df_final[col].astype(str).str.lower().str.strip()
    
    # Aplicamos el cambio
    df_final[col] = df_final[col].replace(traduccion)

print("✅ ¡Listo! Todo ahora dice 'unknown'.")
print("Ejemplo:", df_final[cols_texto[0]].iloc[0]) # Verificación rápida
# Out:
# --- Traduciendo 16 columnas... ---
# ✅ ¡Listo! Todo ahora dice 'unknown'.
# Ejemplo: 1605454

# %%
# --- RESCATE DE LINKS ORIGINALES 🔗 ---

# 1. Identifica las columnas que son URL (Links)
# Ajusta esta lista con los nombres exactos de tus columnas de links
cols_links = ['Horse Profile', 'Company Profile'] 

print(f"Restaurando links originales en: {cols_links}...")

# 2. Pasamos los datos "crudos" del original al final
# (Esto sobreescribe la versión limpia/rota con la versión original/funcional)
for col in cols_links:
    if col in df.columns and col in df_final.columns:
        df_final[col] = df[col] # ¡Aquí vuelve la magia original!
        
        # 3. Limpieza SUAVE (Solo quitamos espacios, NO minúsculas ni regex agresivo)
        # Los links NO se tocan con .lower() ni se les quitan signos
        df_final[col] = df_final[col].astype(str).str.strip()
        
        # Opcional: Si quedaron 'nan' como texto, los pasamos a 'unknown'
        df_final[col] = df_final[col].replace({'nan': 'unknown', 'None': 'unknown'})

print("✅ ¡Links restaurados! Verifica uno:")
print(df_final[cols_links[0]].iloc[0])
# Out:
# Restaurando links originales en: ['Horse Profile', 'Company Profile']...
# ✅ ¡Links restaurados! Verifica uno:
# https://www.equinenow.com/horse-ad-1605454

# %%
import numpy as np

# --- 🚑 OPERACIÓN RESTAURACIÓN TOTAL (Desde el original) ---

# 1. Traemos la columna CRUDA desde el dataframe original (el sucio)
if 'Temperament' in df.columns:
    print("🔄 Recuperando datos originales...")
    df_final['Temperament'] = df['Temperament']

    # 2. Función ultra-sensible (No borra nada que parezca número)
    def limpieza_extrema(valor):
        texto = str(valor).lower().strip()
        if texto in ['nan', 'unknown', 'sin información', 'none', '']:
            return np.nan
        
        # Si tiene la barra (ej: 5/10), extrae el primer número
        if '/' in texto:
            parte = texto.split('/')[0].strip()
            try: return float(parte)
            except: return np.nan
            
        # Si es un número solo (ej: "8")
        try:
            # Quitamos cualquier letra que haya quedado por error
            solo_num = "".join(filter(str.isdigit, texto))
            return float(solo_num) if solo_num else np.nan
        except:
            return np.nan

    # 3. Aplicamos la limpieza
    df_final['Temperament'] = df_final['Temperament'].apply(limpieza_extrema)

    # 4. Calculamos el promedio REAL (solo de los que tienen datos)
    promedio_real = df_final['Temperament'].mean()
    
    if pd.isna(promedio_real):
        print("⚠️ Alerta: ¡Incluso en el original no hay números!")
        promedio_real = 5.0
    else:
        print(f"📊 Promedio real detectado: {round(promedio_real, 2)}")

    # 5. Rellenamos solo los huecos
    df_final['Temperament'] = df_final['Temperament'].fillna(round(promedio_real, 1))

print("\n✅ Resultado final (Primeros 10):")
print(df_final['Temperament'].head(10).tolist())
# Out:
# 🔄 Recuperando datos originales...
# 📊 Promedio real detectado: 3.16
#
# ✅ Resultado final (Primeros 10):
# 1150                                            unknown
# 1074                                            unknown
# 1269  we are a small family farm specializing in the...
# 113                                             unknown
# 1532  billings livestock is a leader in cattle and h...
# 1043                              can arrange shipping.
# 27    home of clear vision few spot appaloosa stalli...
# 1464                                    watch the video
# 1615  small breeder of warmbloods and other sport ho...
# 1707             felix is ready to be trained your way.
# 1619                                            unknown
# 863                                             unknown
# 843   up to the buyer, but we can you find reliable ...
# 727                                             unknown
# 1414     can be arranged but will prefer you to pick up
# 410   iberianhorses aspires to be the main reference...
# 457                                             unknown
# 1870  our website is current see all of our offering...
# 1527  equine training consignments lessons clinics s...
#
#                             Company Name  \
# 1741                             unknown
# 1150                             unknown
# 1074                             unknown
# 1269             circle l walking horses
# 113                              unknown
# 1532                             unknown
# 1043  find your dream horse consignments
# 27                          harmony farm
# 1464              benchmark sport horses
# 1615                             unknown
# 1707                             unknown
# 1619                             unknown
# 863                              unknown
# 843                       gittins horses
# 727                              unknown
# 1414                             unknown
# 410                       iberian horses
# 457                              unknown
# 1870               mahlstedt ranch, inc.
# 1527                     ervin ranch llc
#
#                                         Company Profile      Color Registry  \
# 1741                                                NaN   buckskin  unknown
# 1150                                                NaN    unknown  unknown
# 1074                                                NaN       grey  unknown
# 1269  https://www.equinenow.com/farm/circle_l_walkin...      black   twhbea
# 113                                                 NaN   bay roan     aqha
# 1532                                                NaN   palomino     aqha
# 1043  https://www.equinenow.com/farm/find-your-dream...   buckskin     ghra
# 27    https://www.equinenow.com/farm/harmony-farm-eq...  blue roan  unknown
# 1464  https://www.equinenow.com/farm/benchmark_sport...   palomino  unknown
# 1615                                                NaN    unknown  unknown
# 1707                                                NaN      black    ialha
# 1619                                                NaN  chocolate  unknown
# 863                                                 NaN        bay  unknown
# 843   https://www.equinenow.com/farm/gittins_horses.htm    unknown       jc
# 727                                                 NaN   red roan     aqha
# 1414                                                NaN        bay     aqha
# 410            https://www.equinenow.com/farm-id-594917        bay  unknown
# 457                                                 NaN    unknown     aphc
# 1870  https://www.equinenow.com/farm/mahlstedt_ranch...     sorrel     aqha
# 1527  https://www.equinenow.com/farm/rugged_cross_pe...    unknown  unknown
#
#                             Markings    Age  Has_Face_Markings
# 1741                         unknown  12.00                  0
# 1150                         unknown   5.80                  0
# 1074                         unknown   3.90                  0
# 1269                         unknown   7.80                  0
# 113            small star. two socks   0.80                  1
# 1532                         unknown   5.80                  0
# 1043                          silver   6.80                  0
# 27                           unknown   1.70                  0
# 1464        blaze and four stockings   7.10                  1
# 1615                         unknown   3.85                  0
# 1707  blaze and 3 white socks flashy   3.60                  1
# 1619   bay with two white hind socks   5.10                  0
# 863                          unknown   5.80                  0
# 843                            blaze  12.10                  1
# 727                      star, strip  13.80                  1
# 1414                star, white sock   1.90                  1
# 410                          unknown   3.60                  0
# 457                          unknown   0.80                  0
# 1870                           blaze   0.70                  1
# 1527                         unknown   6.10                  0

# %%
#df_final.to_csv('equinenow_horses_listings_limpio.csv', index=False, encoding='utf-8')

# %%
#df_final.to_parquet('equinenow_horses_listings_limpio.parquet', index=False)
