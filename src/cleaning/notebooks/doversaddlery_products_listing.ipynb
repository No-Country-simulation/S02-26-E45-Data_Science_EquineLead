# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_parquet(
    r"C:\Users\veter\Desktop\nocountry\equipo_45\doversaddlery_products_listing.parquet"
)

# %%
pd.options.display.max_columns = None
df
# Out:
#     Item_ID                                               Name        Stock  \
# 0    360064                          Troxel® Sport 2.0™ Helmet     In stock
# 1    240084     WeatherBeeta® Free Standard Neck Turnout Sheet     In stock
# 2     43229       Rider’s International™ Laced Rein Dog Collar     In stock
# 3    381034  Noble Equestrian™ Ladies' Traditions Paddock B...     In stock
# 4    381037        Tredstep™ Ladies’ Donatello III Dress Boots  10 in stock
# ..      ...                                                ...          ...
# 932  205167  Kastel Denmark Ladies’ Crewneck Long Sleeve Sh...   4 in stock
# 933  381948  TuffRider® Children’s Starter Back-Zip Synthet...   7 in stock
# 934  204177               Goode Rider™ Girls’ Elite Polo Shirt   7 in stock
# 935  205162  Kastel Denmark Ladies’ Quarter-Zip Cap Sleeve ...   9 in stock
# 936  270397                      Himalayan Salt Lick on a Rope     In stock
#
#                                            Description    Price  \
# 0    Browse our carefully curated categories to dis...   $61.99
# 1    Browse our carefully curated categories to dis...  $254.99
# 2    Browse our carefully curated categories to dis...   $19.95
# 3    Browse our carefully curated categories to dis...  $139.95
# 4    Browse our carefully curated categories to dis...  $379.00
# ..                                                 ...      ...
# 932  Browse our carefully curated categories to dis...   $99.00
# 933  Browse our carefully curated categories to dis...  $124.99
# 934  Browse our carefully curated categories to dis...   $75.00
# 935  Browse our carefully curated categories to dis...   $89.00
# 936  Browse our carefully curated categories to dis...   $17.50
#
#                                                 Images  \
# 0    [https://www.doversaddlery.com/cdn/shop/files/...
# 1    [https://www.doversaddlery.com/cdn/shop/files/...
# 2    [https://www.doversaddlery.com/cdn/shop/files/...
# 3    [https://www.doversaddlery.com/cdn/shop/files/...
# 4    [https://www.doversaddlery.com/cdn/shop/files/...
# ..                                                 ...
# 932  [https://www.doversaddlery.com/cdn/shop/files/...
# 933  [https://www.doversaddlery.com/cdn/shop/files/...
# 934  [https://www.doversaddlery.com/cdn/shop/files/...
# 935  [https://www.doversaddlery.com/cdn/shop/files/...
# 936  [https://www.doversaddlery.com/cdn/shop/files/...
#
#                                                    URL
# 0    https://www.doversaddlery.com/collections/helm...
# 1    https://www.doversaddlery.com/collections/hors...
# 2    https://www.doversaddlery.com/collections/farm...
# 3    https://www.doversaddlery.com/collections/ridi...
# 4    https://www.doversaddlery.com/collections/ridi...
# ..                                                 ...
# 932  https://www.doversaddlery.com/collections/new/...
# 933  https://www.doversaddlery.com/collections/kids...
# 934  https://www.doversaddlery.com/collections/clea...
# 935  https://www.doversaddlery.com/collections/new/...
# 936  https://www.doversaddlery.com/collections/stab...
#
# [937 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 937 entries, 0 to 936
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Item_ID      937 non-null    str
#  1   Name         937 non-null    str
#  2   Stock        924 non-null    str
#  3   Description  937 non-null    str
#  4   Price        937 non-null    str
#  5   Images       937 non-null    object
#  6   URL          937 non-null    str
# dtypes: object(1), str(6)
# memory usage: 281.0+ KB

# %%
import numpy as np

# --- 🛍️ CLEANING HORSE PRODUCTS DATABASE (FROM PARQUET) ---

# 1. Usamos el 'df' original
df_prod_clean = df.copy()

print("--- Starting Product Database Cleaning ---")

# 2. LIMPIEZA DE TEXTO (Name, Description, Item_ID)
cols_texto = ['Item_ID', 'Name', 'Description']

for col in cols_texto:
    if col in df_prod_clean.columns:
        df_prod_clean[col] = (df_prod_clean[col]
                              .astype(str)
                              .str.lower()
                              .str.strip()
                              .replace({'nan': 'unknown', 'none': 'unknown', 'sin información': 'unknown'}))

print("✅ Text columns normalized (lowercase & English nans).")

# 3. LIMPIEZA DE PRECIO (De Texto a Número)
if 'Price' in df_prod_clean.columns:
    # Quitamos símbolos de moneda y comas
    df_prod_clean['Price'] = df_prod_clean['Price'].astype(str).str.replace(r'[$,]', '', regex=True)
    df_prod_clean['Price'] = pd.to_numeric(df_prod_clean['Price'], errors='coerce')
    # Rellenamos nulos con la mediana
    df_prod_clean['Price'] = df_prod_clean['Price'].fillna(df_prod_clean['Price'].median())

# 4. LIMPIEZA DE STOCK (De Texto a Número)
if 'Stock' in df_prod_clean.columns:
    # Extraemos el número por si dice "10 units" o algo así
    df_prod_clean['Stock'] = df_prod_clean['Stock'].astype(str).str.extract(r'(\d+)').astype(float)
    # Rellenamos los 13 nulos con 0 para ser conservadores
    df_prod_clean['Stock'] = df_prod_clean['Stock'].fillna(0).astype(int)

print("✅ Price and Stock converted to numbers.")

# 5. PROTEGER LINKS (Images y URL) - No usar .lower() aquí
cols_links = ['Images', 'URL']
for col in cols_links:
    if col in df_prod_clean.columns:
        df_prod_clean[col] = (df_prod_clean[col]
                              .astype(str)
                              .str.replace(r"[\[\]\'\"]", "", regex=True) # Quitar corchetes
                              .str.strip()
                              .replace({'nan': 'unknown'}))

print("✅ Links and Images cleaned but case-sensitive preserved.")

# --- VERIFICACIÓN FINAL ---
print("\n--- FINAL PRODUCT REPORT ---")
print(f"Total rows: {len(df_prod_clean)}")
print(f"Total nulls: {df_prod_clean.isnull().sum().sum()}")
print("\nQuick Preview:")
print(df_prod_clean[['Name', 'Price', 'Stock']].head())
# Out:
# --- Starting Product Database Cleaning ---
# ✅ Text columns normalized (lowercase & English nans).
# ✅ Price and Stock converted to numbers.
# ✅ Links and Images cleaned but case-sensitive preserved.
#
# --- FINAL PRODUCT REPORT ---
# Total rows: 937
# Total nulls: 0
#
# Quick Preview:
#                                                 Name   Price  Stock
# 0                          troxel® sport 2.0™ helmet   61.99      0
# 1     weatherbeeta® free standard neck turnout sheet  254.99      0
# 2       rider’s international™ laced rein dog collar   19.95      0
# 3  noble equestrian™ ladies' traditions paddock b...  139.95      0
# 4        tredstep™ ladies’ donatello iii dress boots  379.00     10

# %%
df_prod_clean.sample(100)
# Out:
#     Item_ID                                               Name  Stock  \
# 421  351369           ds ladies’ stay tight leather half chaps      0
# 656  351543          ladies’ wellesley piped knee-patch breech      2
# 168   38882  tuffrider® ladies’ starter front-zip paddock b...      0
# 602  241065                                  dover dog blanket      1
# 413  352131  kerrits® ladies’ balance coolcore® lite knee-p...      0
# ..      ...                                                ...    ...
# 55   381135  riding sport™ ladies' essential leather zip pa...      0
# 419    4850                                    easyboot® cloud      0
# 562    1650                                         bit butter      0
# 10    22848                     eqyss avocado mist conditioner      0
# 936  270397                      himalayan salt lick on a rope      0
#
#                                            Description   Price  \
# 421  browse our carefully curated categories to dis...   89.95
# 656  browse our carefully curated categories to dis...  109.95
# 168  browse our carefully curated categories to dis...   59.99
# 602  browse our carefully curated categories to dis...   39.95
# 413  browse our carefully curated categories to dis...   99.00
# ..                                                 ...     ...
# 55   browse our carefully curated categories to dis...   89.95
# 419  browse our carefully curated categories to dis...  111.95
# 562  browse our carefully curated categories to dis...   23.95
# 10   browse our carefully curated categories to dis...   23.99
# 936  browse our carefully curated categories to dis...   17.50
#
#                                                 Images  \
# 421  https://www.doversaddlery.com/cdn/shop/files/0...
# 656  https://www.doversaddlery.com/cdn/shop/files/0...
# 168  https://www.doversaddlery.com/cdn/shop/files/0...
# 602  https://www.doversaddlery.com/cdn/shop/files/0...
# 413  https://www.doversaddlery.com/cdn/shop/files/0...
# ..                                                 ...
# 55   https://www.doversaddlery.com/cdn/shop/files/0...
# 419  https://www.doversaddlery.com/cdn/shop/files/0...
# 562  https://www.doversaddlery.com/cdn/shop/files/0...
# 10   https://www.doversaddlery.com/cdn/shop/files/0...
# 936  https://www.doversaddlery.com/cdn/shop/files/0...
#
#                                                    URL
# 421  https://www.doversaddlery.com/collections/ridi...
# 656  https://www.doversaddlery.com/collections/clea...
# 168  https://www.doversaddlery.com/collections/ridi...
# 602  https://www.doversaddlery.com/collections/farm...
# 413  https://www.doversaddlery.com/collections/new/...
# ..                                                 ...
# 55   https://www.doversaddlery.com/collections/ridi...
# 419  https://www.doversaddlery.com/collections/hors...
# 562  https://www.doversaddlery.com/collections/hors...
# 10   https://www.doversaddlery.com/collections/hors...
# 936  https://www.doversaddlery.com/collections/stab...
#
# [100 rows x 7 columns]

# %%
#df_prod_clean.to_parquet('products_listing_limpio.parquet', index=False)
